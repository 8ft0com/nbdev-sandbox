# %% [raw]
# ---
# description: Fill in a module description here
# output-file: deck.html
# title: Deck
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Deck)
# Out:
# ---
#
# [source](https://github.com/8ft0com/nbdev-sandbox/blob/main/nbdev_sandbox/deck.py#L10){target="_blank" style="float:right; font-size:smaller"}
#
# ### Deck
#
# >      Deck ()
#
# A Deck of cards

# %%
d = Deck()
print(d)
# Out:
# AC; 2C; 3C; 4C; 5C; 6C; 7C; 8C; 9C; 10C; JC; QC; KC; AD; 2D; 3D; 4D; 5D; 6D; 7D; 8D; 9D; 10D; JD; QD; KD; AH; 2H; 3H; 4H; 5H; 6H; 7H; 8H; 9H; 10H; JH; QH; KH; AS; 2S; 3S; 4S; 5S; 6S; 7S; 8S; 9S; 10S; JS; QS; KS

# %%
Deck??
# Out:
# Init signature: Deck()
# Docstring:      A Deck of cards
# Type:           type
# Subclasses:
